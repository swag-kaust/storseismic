# %% [markdown]
# # Fine-tuning - Denoising

# %% [markdown]
# We will use the pre-trained StorSeismic model to perform a denoising task. The input and output of the network are adjusted to noisy and clean seismic data, respectively.

# %% [markdown]
# ## Load required modules

# %%
from transformers import BertConfig, BertForMaskedLM
import transformers
import torch.nn.functional as F
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from tqdm import tqdm
import os
import time
from radam import RAdam
import sys
import pandas as pd
import itertools

from storseismic.modules import *
from storseismic.train import run_denoising
from storseismic.utils import *

pd.set_option('display.max_rows', None)
torch.cuda.empty_cache()

params = {
    'savefig.dpi': 600,  # to adjust notebook inline plot size
    'figure.dpi' : 600,
    'axes.labelsize':14,  # fontsize for x and y labels (was 10)
    'axes.titlesize':14,
    'axes.titleweight': 'bold',
    'legend.fontsize': 14,  # was 10
    'xtick.labelsize':12,
    'ytick.labelsize':12,
    'font.family': 'serif',
}
matplotlib.rcParams.update(params)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Fine-tuning configuration

# %%
config_path = "./results/pretrain/"
config = torch.load(os.path.join(config_path, 'config.pt'))

# Training Parameter
config.batch_size = 16
config.loss_fn = "l2" # "l2", "ssim", "ssiml1"
config.optim = "radam" # "adam", "radam"
config.lr = 5e-4
config.epoch = 1000
config.warmup = "none" if config.pre_ln else 0
config.patience = 20

# I/O parameter
config.parent_dir = './results/finetune/denoising/'
config.model_path = './results/pretrain/'
config.dataset = './data/finetune/'

print(config)
# Out:
# BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "batch_size": 16,
#   "classifier_dropout": null,
#   "dataset": "./data/finetune/",
#   "embedding_type": "none",
#   "epoch": 1000,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 256,
#   "initializer_range": 0.02,
#   "input_type": "trace",
#   "intermediate_size": 1024,
#   "layer_norm_eps": 1e-12,
#   "loss_fn": "l2",
#   "lr": 0.0005,
#   "max_position_embeddings": 20,
#   "model_path": "./results/pretrain/",
#   "model_type": "bert",
#   "num_attention_heads": 4,
#   "num_hidden_ffn": 4,
#   "num_hidden_layers": 4,
#   "optim": "radam",
#   "output_attentions": true,
#   "output_hidden_states": true,
#   "output_scores": true,
#   "pad_token_id": 0,
#   "parent_dir": "./results/finetune/denoising/",
#   "patience": 20,
#   "position_embedding_type": "sincos",
#   "pre_ln": true,
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 271,
#   "warmup": "none"
# }

# %% [markdown]
# ### Load data and wrap in Pytorch DataLoader

# %%
train_data = torch.load(os.path.join(config.dataset, 'train_data.pt'))
test_data = torch.load(os.path.join(config.dataset, 'test_data.pt'))

vmin_all = -1
vmax_all = 1

# %%
batch_size = config.batch_size

train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

for i, X in enumerate(train_dataloader):
    if i == 0:
        for j in range(4):
            f, ax = plt.subplots(1, 2, figsize=(10, 5))
            ax[0].imshow(X['inputs_embeds'][j, :, :].swapaxes(0, 1) - X['inputs_embeds'][j, :, :].mean(), 
                         aspect=.1, vmin=vmin_all, vmax=vmax_all, cmap='seismic')
            ax[0].set_title("Input")
            ax[1].imshow(X['labels'][j, :, :].swapaxes(0, 1) - X['labels'][j, :, :].mean(), 
                         aspect=.1, vmin=vmin_all, vmax=vmax_all, cmap='seismic')
            ax[1].set_title("Label")

# %% [markdown]
# ## Setup StorSeismic denoising model

# %%
if not os.path.exists(config.parent_dir):
    os.makedirs(config.parent_dir)

# %% [markdown]
# ### Load pre-trained model

# %%
model = torch.load(os.path.join(config.model_path, "model.pt"))
print(model)
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Linear(in_features=271, out_features=256, bias=True)
#       (position_embeddings): PositionalEncoding(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): Linear(
#       in_features=256, out_features=271, bias=True
#       (decoder): Identity()
#     )
#   )
# )

# %% [markdown]
# ### Evaluate zero-shot performance

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

loss_fn = nn.MSELoss(reduction='mean')

loop_valid = tqdm(test_dataloader, leave=True)
losses_valid = 0
with torch.no_grad():
    for i, batch in enumerate(loop_valid):
        # pull all tensor batches required for training

        # Mask outside loop
        inputs_embeds = batch['inputs_embeds'].to(device)
        labels = batch['labels'].to(device)
        
        outputs = model(inputs_embeds=inputs_embeds.to(device))
        
        loss = loss_fn(outputs.logits, labels)

        losses_valid += loss.item()

        loop_valid.set_description(f'Validation 0')
        loop_valid.set_postfix(loss=loss.item())
        
    avg_valid_loss = losses_valid / len(test_dataloader)

print("Zero-shot loss on test data: {}".format(avg_valid_loss))
# Out:
# Validation 0: 100%|████████████████| 19/19 [00:00<00:00, 53.53it/s, loss=0.0013]
# Zero-shot loss on test data: 0.00143723328916454

# %% [markdown]
# ### Change the prediction head

# %%
model.cls = DenoisingHead(config)
print(model)
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Linear(in_features=271, out_features=256, bias=True)
#       (position_embeddings): PositionalEncoding(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): PreLNBertAttention(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (self): BertSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): PreLNBertSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): PreLNBertIntermediate(
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): PreLNBertOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): DenoisingHead(
#     (predictions): Linear(
#       in_features=256, out_features=271, bias=True
#       (decoder): Identity()
#     )
#   )
# )

# %% [markdown]
# ### Check number of trainable parameters

# %%
def count_parameters(model):
    table = pd.DataFrame(columns=['Name', 'Parameter'])
    total_params = 0
    i = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        total_params+=param
        table.loc[i] = [name] + [param]
        i += 1
    display(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params
    
count_parameters(model)
# Out:
#                                                  Name  Parameter
# 0              bert.embeddings.word_embeddings.weight      69376
# 1                bert.embeddings.word_embeddings.bias        256
# 2                    bert.embeddings.LayerNorm.weight        256
# 3                      bert.embeddings.LayerNorm.bias        256
# 4     bert.encoder.layer.0.attention.LayerNorm.weight        256
# 5       bert.encoder.layer.0.attention.LayerNorm.bias        256
# 6    bert.encoder.layer.0.attention.self.query.weight      65536
# 7      bert.encoder.layer.0.attention.self.query.bias        256
# 8      bert.encoder.layer.0.attention.self.key.weight      65536
# 9        bert.encoder.layer.0.attention.self.key.bias        256
# 10   bert.encoder.layer.0.attention.self.value.weight      65536
# 11     bert.encoder.layer.0.attention.self.value.bias        256
# 12  bert.encoder.layer.0.attention.output.dense.we...      65536
# 13   bert.encoder.layer.0.attention.output.dense.bias        256
# 14  bert.encoder.layer.0.intermediate.LayerNorm.we...        256
# 15   bert.encoder.layer.0.intermediate.LayerNorm.bias        256
# 16     bert.encoder.layer.0.intermediate.dense.weight     262144
# 17       bert.encoder.layer.0.intermediate.dense.bias       1024
# 18           bert.encoder.layer.0.output.dense.weight     262144
# 19             bert.encoder.layer.0.output.dense.bias        256
# 20    bert.encoder.layer.1.attention.LayerNorm.weight        256
# 21      bert.encoder.layer.1.attention.LayerNorm.bias        256
# 22   bert.encoder.layer.1.attention.self.query.weight      65536
# 23     bert.encoder.layer.1.attention.self.query.bias        256
# 24     bert.encoder.layer.1.attention.self.key.weight      65536
# 25       bert.encoder.layer.1.attention.self.key.bias        256
# 26   bert.encoder.layer.1.attention.self.value.weight      65536
# 27     bert.encoder.layer.1.attention.self.value.bias        256
# 28  bert.encoder.layer.1.attention.output.dense.we...      65536
# 29   bert.encoder.layer.1.attention.output.dense.bias        256
# 30  bert.encoder.layer.1.intermediate.LayerNorm.we...        256
# 31   bert.encoder.layer.1.intermediate.LayerNorm.bias        256
# 32     bert.encoder.layer.1.intermediate.dense.weight     262144
# 33       bert.encoder.layer.1.intermediate.dense.bias       1024
# 34           bert.encoder.layer.1.output.dense.weight     262144
# 35             bert.encoder.layer.1.output.dense.bias        256
# 36    bert.encoder.layer.2.attention.LayerNorm.weight        256
# 37      bert.encoder.layer.2.attention.LayerNorm.bias        256
# 38   bert.encoder.layer.2.attention.self.query.weight      65536
# 39     bert.encoder.layer.2.attention.self.query.bias        256
# 40     bert.encoder.layer.2.attention.self.key.weight      65536
# 41       bert.encoder.layer.2.attention.self.key.bias        256
# 42   bert.encoder.layer.2.attention.self.value.weight      65536
# 43     bert.encoder.layer.2.attention.self.value.bias        256
# 44  bert.encoder.layer.2.attention.output.dense.we...      65536
# 45   bert.encoder.layer.2.attention.output.dense.bias        256
# 46  bert.encoder.layer.2.intermediate.LayerNorm.we...        256
# 47   bert.encoder.layer.2.intermediate.LayerNorm.bias        256
# 48     bert.encoder.layer.2.intermediate.dense.weight     262144
# 49       bert.encoder.layer.2.intermediate.dense.bias       1024
# 50           bert.encoder.layer.2.output.dense.weight     262144
# 51             bert.encoder.layer.2.output.dense.bias        256
# 52    bert.encoder.layer.3.attention.LayerNorm.weight        256
# 53      bert.encoder.layer.3.attention.LayerNorm.bias        256
# 54   bert.encoder.layer.3.attention.self.query.weight      65536
# 55     bert.encoder.layer.3.attention.self.query.bias        256
# 56     bert.encoder.layer.3.attention.self.key.weight      65536
# 57       bert.encoder.layer.3.attention.self.key.bias        256
# 58   bert.encoder.layer.3.attention.self.value.weight      65536
# 59     bert.encoder.layer.3.attention.self.value.bias        256
# 60  bert.encoder.layer.3.attention.output.dense.we...      65536
# 61   bert.encoder.layer.3.attention.output.dense.bias        256
# 62  bert.encoder.layer.3.intermediate.LayerNorm.we...        256
# 63   bert.encoder.layer.3.intermediate.LayerNorm.bias        256
# 64     bert.encoder.layer.3.intermediate.dense.weight     262144
# 65       bert.encoder.layer.3.intermediate.dense.bias       1024
# 66           bert.encoder.layer.3.output.dense.weight     262144
# 67             bert.encoder.layer.3.output.dense.bias        256
# 68                             cls.predictions.weight      69376
# 69                               cls.predictions.bias        271
# Total Trainable Params: 3298831
# 3298831

# %% [markdown]
# #### Send model to device

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
print("Using device: {}".format(device))
# Out:
# Using device: cuda

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set up training hyperparameters

# %%
# Optimizer
optim = RAdam(model.parameters(), lr=config.lr)

# Loss
loss_fn = nn.MSELoss(reduction='mean')

# Number of epochs
epochs = config.epoch

# %% [markdown]
# ### Train

# %%
# %matplotlib notebook

plt.ion()
f, ax = plt.subplots(figsize=(4, 3))
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
model, avg_train_loss, avg_valid_loss, time_per_epoch = \
run_denoising(model, optim, loss_fn, train_dataloader, test_dataloader, epochs, device, 
              tmp_dir=config.parent_dir, patience=config.patience, plot=True, f=f, ax=ax)

# %matplotlib inline
plt.ioff()
# Out:
#   0%|                                                    | 0/75 [00:00<?, ?it/s]/home/randycm/anaconda3/envs/transformers-3/lib/python3.8/site-packages/radam/radam.py:58: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# Epoch 0: 100%|████████████████████| 75/75 [00:02<00:00, 32.12it/s, loss=0.00995]
# Validation 0: 100%|██████████████| 19/19 [00:00<00:00, 141.43it/s, loss=0.00971]
# Epoch time: 2.48 s
# Total time elapsed: 2.48 s
# ---------------------------------------
# Validation loss decreased (inf --> 0.010079).  Saving model ...
# Epoch 1: 100%|████████████████████| 75/75 [00:02<00:00, 32.58it/s, loss=0.00626]
# Validation 1: 100%|██████████████| 19/19 [00:00<00:00, 139.52it/s, loss=0.00713]
# Epoch time: 2.45 s
# Total time elapsed: 5.01 s
# ---------------------------------------
# Validation loss decreased (0.010079 --> 0.006490).  Saving model ...
# Epoch 2: 100%|████████████████████| 75/75 [00:02<00:00, 32.08it/s, loss=0.00409]
# Validation 2: 100%|███████████████| 19/19 [00:00<00:00, 131.43it/s, loss=0.0038]
# Epoch time: 2.49 s
# Total time elapsed: 7.58 s
# ---------------------------------------
# Validation loss decreased (0.006490 --> 0.004354).  Saving model ...
# Epoch 3: 100%|████████████████████| 75/75 [00:02<00:00, 26.15it/s, loss=0.00334]
# Validation 3: 100%|██████████████| 19/19 [00:00<00:00, 134.59it/s, loss=0.00346]
# Epoch time: 3.02 s
# Total time elapsed: 10.67 s
# ---------------------------------------
# Validation loss decreased (0.004354 --> 0.003257).  Saving model ...
# Epoch 4: 100%|█████████████████████| 75/75 [00:02<00:00, 27.20it/s, loss=0.0024]
# Validation 4: 100%|██████████████| 19/19 [00:00<00:00, 134.45it/s, loss=0.00248]
# Epoch time: 2.91 s
# Total time elapsed: 13.65 s
# ---------------------------------------
# Validation loss decreased (0.003257 --> 0.002520).  Saving model ...
# Epoch 5: 100%|████████████████████| 75/75 [00:02<00:00, 28.65it/s, loss=0.00153]
# Validation 5: 100%|██████████████| 19/19 [00:00<00:00, 123.95it/s, loss=0.00243]
# Epoch time: 2.78 s
# Total time elapsed: 16.50 s
# ---------------------------------------
# Validation loss decreased (0.002520 --> 0.002088).  Saving model ...
# Epoch 6: 100%|████████████████████| 75/75 [00:02<00:00, 32.09it/s, loss=0.00205]
# Validation 6: 100%|██████████████| 19/19 [00:00<00:00, 124.83it/s, loss=0.00183]
# Epoch time: 2.50 s
# Total time elapsed: 19.08 s
# ---------------------------------------
# Validation loss decreased (0.002088 --> 0.001801).  Saving model ...
# Epoch 7: 100%|████████████████████| 75/75 [00:02<00:00, 30.33it/s, loss=0.00155]
# Validation 7: 100%|██████████████| 19/19 [00:00<00:00, 140.90it/s, loss=0.00144]
# Epoch time: 2.61 s
# Total time elapsed: 21.77 s
# ---------------------------------------
# Validation loss decreased (0.001801 --> 0.001613).  Saving model ...
# Epoch 8: 100%|████████████████████| 75/75 [00:02<00:00, 31.57it/s, loss=0.00134]
# Validation 8: 100%|██████████████| 19/19 [00:00<00:00, 141.89it/s, loss=0.00149]
# Epoch time: 2.52 s
# Total time elapsed: 24.36 s
# ---------------------------------------
# Validation loss decreased (0.001613 --> 0.001477).  Saving model ...
# Epoch 9: 100%|████████████████████| 75/75 [00:02<00:00, 32.69it/s, loss=0.00128]
# Validation 9: 100%|██████████████| 19/19 [00:00<00:00, 139.13it/s, loss=0.00148]
# Epoch time: 2.44 s
# Total time elapsed: 26.87 s
# ---------------------------------------
# Validation loss decreased (0.001477 --> 0.001375).  Saving model ...
# Epoch 10: 100%|███████████████████| 75/75 [00:02<00:00, 30.62it/s, loss=0.00119]
# Validation 10: 100%|█████████████| 19/19 [00:00<00:00, 139.04it/s, loss=0.00132]
# Epoch time: 2.59 s
# Total time elapsed: 29.54 s
# ---------------------------------------
# Validation loss decreased (0.001375 --> 0.001287).  Saving model ...
# Epoch 11: 100%|███████████████████| 75/75 [00:02<00:00, 32.53it/s, loss=0.00113]
# Validation 11: 100%|██████████████| 19/19 [00:00<00:00, 138.97it/s, loss=0.0016]
# Epoch time: 2.45 s
# Total time elapsed: 32.06 s
# ---------------------------------------
# Validation loss decreased (0.001287 --> 0.001238).  Saving model ...
# Epoch 12: 100%|███████████████████| 75/75 [00:02<00:00, 32.93it/s, loss=0.00111]
# Validation 12: 100%|██████████████| 19/19 [00:00<00:00, 140.85it/s, loss=0.0011]
# Epoch time: 2.42 s
# Total time elapsed: 34.55 s
# ---------------------------------------
# Validation loss decreased (0.001238 --> 0.001169).  Saving model ...
# Epoch 13: 100%|██████████████████| 75/75 [00:02<00:00, 31.26it/s, loss=0.000879]
# Validation 13: 100%|████████████| 19/19 [00:00<00:00, 138.24it/s, loss=0.000866]
# Epoch time: 2.54 s
# Total time elapsed: 37.17 s
# ---------------------------------------
# Validation loss decreased (0.001169 --> 0.001128).  Saving model ...
# Epoch 14: 100%|██████████████████| 75/75 [00:02<00:00, 26.17it/s, loss=0.000967]
# Validation 14: 100%|█████████████| 19/19 [00:00<00:00, 122.52it/s, loss=0.00112]
# Epoch time: 3.03 s
# Total time elapsed: 40.27 s
# ---------------------------------------
# Validation loss decreased (0.001128 --> 0.001095).  Saving model ...
# Epoch 15: 100%|██████████████████| 75/75 [00:02<00:00, 26.36it/s, loss=0.000837]
# Validation 15: 100%|█████████████| 19/19 [00:00<00:00, 136.10it/s, loss=0.00125]
# Epoch time: 2.99 s
# Total time elapsed: 43.34 s
# ---------------------------------------
# Validation loss decreased (0.001095 --> 0.001055).  Saving model ...
# Epoch 16: 100%|██████████████████| 75/75 [00:02<00:00, 26.31it/s, loss=0.000829]
# Validation 16: 100%|████████████| 19/19 [00:00<00:00, 135.10it/s, loss=0.000864]
# Epoch time: 3.00 s
# Total time elapsed: 46.41 s
# ---------------------------------------
# Validation loss decreased (0.001055 --> 0.001022).  Saving model ...
# Epoch 17: 100%|██████████████████| 75/75 [00:02<00:00, 26.48it/s, loss=0.000804]
# Validation 17: 100%|█████████████| 19/19 [00:00<00:00, 127.83it/s, loss=0.00098]
# Epoch time: 2.99 s
# Total time elapsed: 49.47 s
# ---------------------------------------
# Validation loss decreased (0.001022 --> 0.000997).  Saving model ...
# Epoch 18: 100%|██████████████████| 75/75 [00:02<00:00, 26.26it/s, loss=0.000837]
# Validation 18: 100%|████████████| 19/19 [00:00<00:00, 134.51it/s, loss=0.000945]
# Epoch time: 3.00 s
# Total time elapsed: 52.54 s
# ---------------------------------------
# Validation loss decreased (0.000997 --> 0.000979).  Saving model ...
# Epoch 19: 100%|██████████████████| 75/75 [00:02<00:00, 26.53it/s, loss=0.000791]
# Validation 19: 100%|████████████| 19/19 [00:00<00:00, 133.54it/s, loss=0.000986]
# Epoch time: 2.98 s
# Total time elapsed: 55.59 s
# ---------------------------------------
# Validation loss decreased (0.000979 --> 0.000958).  Saving model ...
# Epoch 20: 100%|██████████████████| 75/75 [00:02<00:00, 26.29it/s, loss=0.000819]
# Validation 20: 100%|███████████████| 19/19 [00:00<00:00, 133.58it/s, loss=0.001]
# Epoch time: 3.00 s
# Total time elapsed: 58.66 s
# ---------------------------------------
# Validation loss decreased (0.000958 --> 0.000941).  Saving model ...
# Epoch 21: 100%|██████████████████| 75/75 [00:02<00:00, 26.67it/s, loss=0.000808]
# Validation 21: 100%|████████████| 19/19 [00:00<00:00, 131.53it/s, loss=0.000834]
# Epoch time: 2.96 s
# Total time elapsed: 61.70 s
# ---------------------------------------
# Validation loss decreased (0.000941 --> 0.000926).  Saving model ...
# Epoch 22: 100%|██████████████████| 75/75 [00:02<00:00, 26.57it/s, loss=0.000715]
# Validation 22: 100%|█████████████| 19/19 [00:00<00:00, 136.74it/s, loss=0.00108]
# Epoch time: 2.97 s
# Total time elapsed: 64.74 s
# ---------------------------------------
# Validation loss decreased (0.000926 --> 0.000911).  Saving model ...
# Epoch 23: 100%|██████████████████| 75/75 [00:02<00:00, 26.30it/s, loss=0.000662]
# Validation 23: 100%|████████████| 19/19 [00:00<00:00, 134.45it/s, loss=0.000842]
# Epoch time: 3.00 s
# Total time elapsed: 67.82 s
# ---------------------------------------
# Validation loss decreased (0.000911 --> 0.000909).  Saving model ...
# Epoch 24: 100%|██████████████████| 75/75 [00:02<00:00, 26.34it/s, loss=0.000851]
# Validation 24: 100%|████████████| 19/19 [00:00<00:00, 138.08it/s, loss=0.000841]
# Epoch time: 2.99 s
# Total time elapsed: 70.88 s
# ---------------------------------------
# Validation loss decreased (0.000909 --> 0.000885).  Saving model ...
# Epoch 25: 100%|██████████████████| 75/75 [00:02<00:00, 26.47it/s, loss=0.000727]
# Validation 25: 100%|█████████████| 19/19 [00:00<00:00, 135.88it/s, loss=0.00106]
# Epoch time: 2.98 s
# Total time elapsed: 73.94 s
# ---------------------------------------
# Validation loss decreased (0.000885 --> 0.000883).  Saving model ...
# Epoch 26: 100%|██████████████████| 75/75 [00:02<00:00, 26.17it/s, loss=0.000767]
# Validation 26: 100%|█████████████| 19/19 [00:00<00:00, 136.65it/s, loss=0.00069]
# Epoch time: 3.01 s
# Total time elapsed: 77.02 s
# ---------------------------------------
# Validation loss decreased (0.000883 --> 0.000873).  Saving model ...
# Epoch 27: 100%|██████████████████| 75/75 [00:02<00:00, 26.23it/s, loss=0.000573]
# Validation 27: 100%|███████████████| 19/19 [00:00<00:00, 136.45it/s, loss=0.001]
# Epoch time: 3.01 s
# Total time elapsed: 80.10 s
# ---------------------------------------
# Validation loss decreased (0.000873 --> 0.000862).  Saving model ...
# Epoch 28: 100%|██████████████████| 75/75 [00:02<00:00, 26.67it/s, loss=0.000634]
# Validation 28: 100%|█████████████| 19/19 [00:00<00:00, 137.43it/s, loss=0.00112]
# Epoch time: 2.96 s
# Total time elapsed: 83.13 s
# ---------------------------------------
# Validation loss decreased (0.000862 --> 0.000859).  Saving model ...
# Epoch 29: 100%|██████████████████| 75/75 [00:02<00:00, 26.44it/s, loss=0.000657]
# Validation 29: 100%|████████████| 19/19 [00:00<00:00, 131.83it/s, loss=0.000831]
# Epoch time: 2.99 s
# Total time elapsed: 86.19 s
# ---------------------------------------
# Validation loss decreased (0.000859 --> 0.000848).  Saving model ...
# Epoch 30: 100%|██████████████████| 75/75 [00:02<00:00, 26.39it/s, loss=0.000583]
# Validation 30: 100%|█████████████| 19/19 [00:00<00:00, 136.99it/s, loss=0.00109]
# Epoch time: 2.99 s
# Total time elapsed: 89.25 s
# ---------------------------------------
# Validation loss decreased (0.000848 --> 0.000846).  Saving model ...
# Epoch 31: 100%|██████████████████| 75/75 [00:02<00:00, 26.64it/s, loss=0.000506]
# Validation 31: 100%|████████████| 19/19 [00:00<00:00, 136.05it/s, loss=0.000571]
# Epoch time: 2.96 s
# Total time elapsed: 92.28 s
# ---------------------------------------
# Validation loss decreased (0.000846 --> 0.000832).  Saving model ...
# Epoch 32: 100%|██████████████████| 75/75 [00:02<00:00, 26.50it/s, loss=0.000606]
# Validation 32: 100%|█████████████| 19/19 [00:00<00:00, 134.64it/s, loss=0.00108]
# Epoch time: 2.98 s
# Total time elapsed: 95.33 s
# ---------------------------------------
# Validation loss decreased (0.000832 --> 0.000830).  Saving model ...
# Epoch 33: 100%|███████████████████| 75/75 [00:02<00:00, 26.46it/s, loss=0.00055]
# Validation 33: 100%|████████████| 19/19 [00:00<00:00, 131.12it/s, loss=0.000983]
# Epoch time: 2.99 s
# Total time elapsed: 98.39 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 34: 100%|██████████████████| 75/75 [00:02<00:00, 26.23it/s, loss=0.000536]
# Validation 34: 100%|████████████| 19/19 [00:00<00:00, 132.43it/s, loss=0.000804]
# Epoch time: 3.01 s
# Total time elapsed: 101.45 s
# ---------------------------------------
# Validation loss decreased (0.000830 --> 0.000819).  Saving model ...
# Epoch 35: 100%|███████████████████| 75/75 [00:02<00:00, 26.48it/s, loss=0.00055]
# Validation 35: 100%|████████████| 19/19 [00:00<00:00, 134.02it/s, loss=0.000825]
# Epoch time: 2.98 s
# Total time elapsed: 104.50 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 36: 100%|██████████████████| 75/75 [00:02<00:00, 26.32it/s, loss=0.000482]
# Validation 36: 100%|████████████| 19/19 [00:00<00:00, 122.11it/s, loss=0.000783]
# Epoch time: 3.01 s
# Total time elapsed: 107.56 s
# ---------------------------------------
# Validation loss decreased (0.000819 --> 0.000810).  Saving model ...
# Epoch 37: 100%|███████████████████| 75/75 [00:02<00:00, 26.63it/s, loss=0.00056]
# Validation 37: 100%|████████████| 19/19 [00:00<00:00, 136.18it/s, loss=0.000709]
# Epoch time: 2.96 s
# Total time elapsed: 110.60 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 38: 100%|██████████████████| 75/75 [00:02<00:00, 26.44it/s, loss=0.000508]
# Validation 38: 100%|████████████| 19/19 [00:00<00:00, 137.01it/s, loss=0.000821]
# Epoch time: 2.98 s
# Total time elapsed: 113.62 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 39: 100%|██████████████████| 75/75 [00:02<00:00, 27.29it/s, loss=0.000457]
# Validation 39: 100%|████████████| 19/19 [00:00<00:00, 140.85it/s, loss=0.000816]
# Epoch time: 2.89 s
# Total time elapsed: 116.56 s
# ---------------------------------------
# Validation loss decreased (0.000810 --> 0.000805).  Saving model ...
# Epoch 40: 100%|██████████████████| 75/75 [00:02<00:00, 31.04it/s, loss=0.000545]
# Validation 40: 100%|████████████| 19/19 [00:00<00:00, 140.19it/s, loss=0.000765]
# Epoch time: 2.56 s
# Total time elapsed: 119.19 s
# ---------------------------------------
# Validation loss decreased (0.000805 --> 0.000801).  Saving model ...
# Epoch 41: 100%|██████████████████| 75/75 [00:02<00:00, 33.11it/s, loss=0.000532]
# Validation 41: 100%|█████████████| 19/19 [00:00<00:00, 139.59it/s, loss=0.00101]
# Epoch time: 2.41 s
# Total time elapsed: 121.68 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 42: 100%|██████████████████| 75/75 [00:02<00:00, 32.91it/s, loss=0.000571]
# Validation 42: 100%|████████████| 19/19 [00:00<00:00, 138.17it/s, loss=0.000782]
# Epoch time: 2.42 s
# Total time elapsed: 124.15 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 43: 100%|██████████████████| 75/75 [00:02<00:00, 28.35it/s, loss=0.000533]
# Validation 43: 100%|████████████| 19/19 [00:00<00:00, 133.11it/s, loss=0.000675]
# Epoch time: 2.80 s
# Total time elapsed: 126.99 s
# ---------------------------------------
# Validation loss decreased (0.000801 --> 0.000796).  Saving model ...
# Epoch 44: 100%|██████████████████| 75/75 [00:02<00:00, 26.15it/s, loss=0.000515]
# Validation 44: 100%|████████████| 19/19 [00:00<00:00, 137.48it/s, loss=0.000608]
# Epoch time: 3.01 s
# Total time elapsed: 130.08 s
# ---------------------------------------
# Validation loss decreased (0.000796 --> 0.000790).  Saving model ...
# Epoch 45: 100%|██████████████████| 75/75 [00:02<00:00, 26.13it/s, loss=0.000509]
# Validation 45: 100%|████████████| 19/19 [00:00<00:00, 133.68it/s, loss=0.000775]
# Epoch time: 3.02 s
# Total time elapsed: 133.18 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 46: 100%|██████████████████| 75/75 [00:02<00:00, 26.05it/s, loss=0.000457]
# Validation 46: 100%|████████████| 19/19 [00:00<00:00, 137.94it/s, loss=0.000851]
# Epoch time: 3.02 s
# Total time elapsed: 136.25 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 47: 100%|██████████████████| 75/75 [00:02<00:00, 28.11it/s, loss=0.000446]
# Validation 47: 100%|████████████| 19/19 [00:00<00:00, 142.93it/s, loss=0.000727]
# Epoch time: 2.81 s
# Total time elapsed: 139.11 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 48: 100%|██████████████████| 75/75 [00:02<00:00, 32.04it/s, loss=0.000397]
# Validation 48: 100%|████████████| 19/19 [00:00<00:00, 139.16it/s, loss=0.000772]
# Epoch time: 2.48 s
# Total time elapsed: 141.64 s
# ---------------------------------------
# Validation loss decreased (0.000790 --> 0.000785).  Saving model ...
# Epoch 49: 100%|██████████████████| 75/75 [00:02<00:00, 32.31it/s, loss=0.000477]
# Validation 49: 100%|█████████████| 19/19 [00:00<00:00, 142.70it/s, loss=0.00055]
# Epoch time: 2.46 s
# Total time elapsed: 144.18 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 50: 100%|██████████████████| 75/75 [00:02<00:00, 32.79it/s, loss=0.000452]
# Validation 50: 100%|████████████| 19/19 [00:00<00:00, 142.33it/s, loss=0.000842]
# Epoch time: 2.43 s
# Total time elapsed: 146.66 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 51: 100%|██████████████████| 75/75 [00:02<00:00, 32.98it/s, loss=0.000428]
# Validation 51: 100%|████████████| 19/19 [00:00<00:00, 112.00it/s, loss=0.000637]
# Epoch time: 2.45 s
# Total time elapsed: 149.16 s
# ---------------------------------------
# Validation loss decreased (0.000785 --> 0.000782).  Saving model ...
# Epoch 52: 100%|██████████████████| 75/75 [00:02<00:00, 32.86it/s, loss=0.000463]
# Validation 52: 100%|████████████| 19/19 [00:00<00:00, 142.14it/s, loss=0.000824]
# Epoch time: 2.42 s
# Total time elapsed: 151.66 s
# ---------------------------------------
# Validation loss decreased (0.000782 --> 0.000780).  Saving model ...
# Epoch 53: 100%|██████████████████| 75/75 [00:02<00:00, 32.70it/s, loss=0.000446]
# Validation 53: 100%|████████████| 19/19 [00:00<00:00, 137.60it/s, loss=0.000858]
# Epoch time: 2.44 s
# Total time elapsed: 154.17 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 54: 100%|██████████████████| 75/75 [00:02<00:00, 32.73it/s, loss=0.000403]
# Validation 54: 100%|████████████| 19/19 [00:00<00:00, 147.83it/s, loss=0.000544]
# Epoch time: 2.43 s
# Total time elapsed: 156.65 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 55: 100%|██████████████████| 75/75 [00:02<00:00, 32.16it/s, loss=0.000436]
# Validation 55: 100%|████████████| 19/19 [00:00<00:00, 125.68it/s, loss=0.000848]
# Epoch time: 2.49 s
# Total time elapsed: 159.19 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 56: 100%|██████████████████| 75/75 [00:02<00:00, 26.55it/s, loss=0.000451]
# Validation 56: 100%|████████████| 19/19 [00:00<00:00, 133.04it/s, loss=0.000897]
# Epoch time: 2.98 s
# Total time elapsed: 162.21 s
# ---------------------------------------
# Validation loss decreased (0.000780 --> 0.000773).  Saving model ...
# Epoch 57: 100%|██████████████████| 75/75 [00:02<00:00, 26.90it/s, loss=0.000392]
# Validation 57: 100%|████████████| 19/19 [00:00<00:00, 137.38it/s, loss=0.000654]
# Epoch time: 2.93 s
# Total time elapsed: 165.21 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 58: 100%|███████████████████| 75/75 [00:02<00:00, 32.87it/s, loss=0.00043]
# Validation 58: 100%|████████████| 19/19 [00:00<00:00, 121.46it/s, loss=0.000721]
# Epoch time: 2.44 s
# Total time elapsed: 167.70 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 59: 100%|██████████████████| 75/75 [00:02<00:00, 32.94it/s, loss=0.000508]
# Validation 59: 100%|██████████████| 19/19 [00:00<00:00, 138.35it/s, loss=0.0007]
# Epoch time: 2.42 s
# Total time elapsed: 170.19 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 60: 100%|██████████████████| 75/75 [00:02<00:00, 28.12it/s, loss=0.000389]
# Validation 60: 100%|████████████| 19/19 [00:00<00:00, 133.48it/s, loss=0.000716]
# Epoch time: 2.82 s
# Total time elapsed: 173.05 s
# ---------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 61: 100%|██████████████████| 75/75 [00:02<00:00, 27.25it/s, loss=0.000429]
# Validation 61: 100%|████████████| 19/19 [00:00<00:00, 140.44it/s, loss=0.000654]
# Epoch time: 2.90 s
# Total time elapsed: 176.00 s
# ---------------------------------------
# Validation loss decreased (0.000773 --> 0.000766).  Saving model ...
# Epoch 62: 100%|██████████████████| 75/75 [00:02<00:00, 32.24it/s, loss=0.000418]
# Validation 62: 100%|████████████| 19/19 [00:00<00:00, 146.44it/s, loss=0.000631]
# Epoch time: 2.46 s
# Total time elapsed: 178.54 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 63: 100%|████████████████████| 75/75 [00:02<00:00, 32.87it/s, loss=0.0004]
# Validation 63: 100%|████████████| 19/19 [00:00<00:00, 143.14it/s, loss=0.000583]
# Epoch time: 2.42 s
# Total time elapsed: 181.00 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 64: 100%|██████████████████| 75/75 [00:02<00:00, 32.52it/s, loss=0.000436]
# Validation 64: 100%|████████████| 19/19 [00:00<00:00, 143.84it/s, loss=0.000773]
# Epoch time: 2.45 s
# Total time elapsed: 183.50 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 65: 100%|██████████████████| 75/75 [00:02<00:00, 32.44it/s, loss=0.000386]
# Validation 65: 100%|████████████| 19/19 [00:00<00:00, 135.53it/s, loss=0.000842]
# Epoch time: 2.46 s
# Total time elapsed: 186.00 s
# ---------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 66: 100%|██████████████████| 75/75 [00:02<00:00, 33.16it/s, loss=0.000382]
# Validation 66: 100%|████████████| 19/19 [00:00<00:00, 138.80it/s, loss=0.000969]
# Epoch time: 2.41 s
# Total time elapsed: 188.46 s
# ---------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 67: 100%|██████████████████| 75/75 [00:02<00:00, 32.83it/s, loss=0.000425]
# Validation 67: 100%|████████████| 19/19 [00:00<00:00, 139.46it/s, loss=0.000633]
# Epoch time: 2.43 s
# Total time elapsed: 190.93 s
# ---------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 68: 100%|██████████████████| 75/75 [00:02<00:00, 32.63it/s, loss=0.000394]
# Validation 68: 100%|████████████| 19/19 [00:00<00:00, 120.04it/s, loss=0.000878]
# Epoch time: 2.46 s
# Total time elapsed: 193.44 s
# ---------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 69: 100%|███████████████████| 75/75 [00:02<00:00, 32.52it/s, loss=0.00042]
# Validation 69: 100%|████████████| 19/19 [00:00<00:00, 140.38it/s, loss=0.000933]
# Epoch time: 2.45 s
# Total time elapsed: 195.94 s
# ---------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 70: 100%|██████████████████| 75/75 [00:02<00:00, 32.90it/s, loss=0.000368]
# Validation 70: 100%|████████████| 19/19 [00:00<00:00, 142.04it/s, loss=0.000619]
# Epoch time: 2.42 s
# Total time elapsed: 198.49 s
# ---------------------------------------
# EarlyStopping counter: 9 out of 20
# Epoch 71: 100%|██████████████████| 75/75 [00:02<00:00, 33.04it/s, loss=0.000403]
# Validation 71: 100%|████████████| 19/19 [00:00<00:00, 140.22it/s, loss=0.000901]
# Epoch time: 2.41 s
# Total time elapsed: 200.95 s
# ---------------------------------------
# EarlyStopping counter: 10 out of 20
# Epoch 72: 100%|██████████████████| 75/75 [00:02<00:00, 32.55it/s, loss=0.000403]
# Validation 72: 100%|████████████| 19/19 [00:00<00:00, 141.80it/s, loss=0.000966]
# Epoch time: 2.44 s
# Total time elapsed: 203.44 s
# ---------------------------------------
# EarlyStopping counter: 11 out of 20
# Epoch 73: 100%|██████████████████| 75/75 [00:02<00:00, 31.86it/s, loss=0.000388]
# Validation 73: 100%|████████████| 19/19 [00:00<00:00, 138.94it/s, loss=0.000535]
# Epoch time: 2.50 s
# Total time elapsed: 205.98 s
# ---------------------------------------
# Validation loss decreased (0.000766 --> 0.000765).  Saving model ...
# Epoch 74: 100%|██████████████████| 75/75 [00:02<00:00, 32.99it/s, loss=0.000381]
# Validation 74: 100%|████████████| 19/19 [00:00<00:00, 139.53it/s, loss=0.000578]
# Epoch time: 2.42 s
# Total time elapsed: 208.47 s
# ---------------------------------------
# Validation loss decreased (0.000765 --> 0.000764).  Saving model ...
# Epoch 75: 100%|██████████████████| 75/75 [00:02<00:00, 32.98it/s, loss=0.000411]
# Validation 75: 100%|████████████| 19/19 [00:00<00:00, 139.85it/s, loss=0.000861]
# Epoch time: 2.42 s
# Total time elapsed: 210.96 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 76: 100%|██████████████████| 75/75 [00:02<00:00, 32.88it/s, loss=0.000389]
# Validation 76: 100%|████████████| 19/19 [00:00<00:00, 139.90it/s, loss=0.000865]
# Epoch time: 2.42 s
# Total time elapsed: 213.43 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 77: 100%|██████████████████| 75/75 [00:02<00:00, 32.99it/s, loss=0.000419]
# Validation 77: 100%|████████████| 19/19 [00:00<00:00, 139.94it/s, loss=0.000805]
# Epoch time: 2.42 s
# Total time elapsed: 215.89 s
# ---------------------------------------
# Validation loss decreased (0.000764 --> 0.000754).  Saving model ...
# Epoch 78: 100%|██████████████████| 75/75 [00:02<00:00, 30.75it/s, loss=0.000377]
# Validation 78: 100%|████████████| 19/19 [00:00<00:00, 134.46it/s, loss=0.000595]
# Epoch time: 2.59 s
# Total time elapsed: 218.56 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 79: 100%|███████████████████| 75/75 [00:02<00:00, 32.67it/s, loss=0.00036]
# Validation 79: 100%|█████████████| 19/19 [00:00<00:00, 143.12it/s, loss=0.00073]
# Epoch time: 2.44 s
# Total time elapsed: 221.05 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 80: 100%|███████████████████| 75/75 [00:02<00:00, 32.90it/s, loss=0.00037]
# Validation 80: 100%|████████████| 19/19 [00:00<00:00, 141.76it/s, loss=0.000636]
# Epoch time: 2.42 s
# Total time elapsed: 223.52 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 81: 100%|████████████████████| 75/75 [00:02<00:00, 33.02it/s, loss=0.0004]
# Validation 81: 100%|████████████| 19/19 [00:00<00:00, 137.32it/s, loss=0.000679]
# Epoch time: 2.42 s
# Total time elapsed: 225.98 s
# ---------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 82: 100%|██████████████████| 75/75 [00:02<00:00, 32.67it/s, loss=0.000333]
# Validation 82: 100%|██████████████| 19/19 [00:00<00:00, 141.42it/s, loss=0.0012]
# Epoch time: 2.44 s
# Total time elapsed: 228.47 s
# ---------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 83: 100%|██████████████████| 75/75 [00:02<00:00, 32.72it/s, loss=0.000374]
# Validation 83: 100%|████████████| 19/19 [00:00<00:00, 139.27it/s, loss=0.000578]
# Epoch time: 2.44 s
# Total time elapsed: 230.95 s
# ---------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 84: 100%|██████████████████| 75/75 [00:02<00:00, 32.21it/s, loss=0.000311]
# Validation 84: 100%|████████████| 19/19 [00:00<00:00, 142.90it/s, loss=0.000939]
# Epoch time: 2.47 s
# Total time elapsed: 233.47 s
# ---------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 85: 100%|██████████████████| 75/75 [00:02<00:00, 33.02it/s, loss=0.000362]
# Validation 85: 100%|████████████| 19/19 [00:00<00:00, 140.20it/s, loss=0.000721]
# Epoch time: 2.41 s
# Total time elapsed: 235.93 s
# ---------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 86: 100%|██████████████████| 75/75 [00:02<00:00, 32.77it/s, loss=0.000325]
# Validation 86: 100%|████████████| 19/19 [00:00<00:00, 143.51it/s, loss=0.000823]
# Epoch time: 2.43 s
# Total time elapsed: 238.41 s
# ---------------------------------------
# Validation loss decreased (0.000754 --> 0.000754).  Saving model ...
# Epoch 87: 100%|██████████████████| 75/75 [00:02<00:00, 32.43it/s, loss=0.000379]
# Validation 87: 100%|████████████| 19/19 [00:00<00:00, 139.27it/s, loss=0.000734]
# Epoch time: 2.46 s
# Total time elapsed: 240.94 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 88: 100%|██████████████████| 75/75 [00:02<00:00, 32.95it/s, loss=0.000333]
# Validation 88: 100%|████████████| 19/19 [00:00<00:00, 144.83it/s, loss=0.000925]
# Epoch time: 2.41 s
# Total time elapsed: 243.41 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 89: 100%|██████████████████| 75/75 [00:02<00:00, 32.90it/s, loss=0.000379]
# Validation 89: 100%|████████████| 19/19 [00:00<00:00, 138.58it/s, loss=0.000867]
# Epoch time: 2.42 s
# Total time elapsed: 245.88 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 90: 100%|██████████████████| 75/75 [00:02<00:00, 32.94it/s, loss=0.000347]
# Validation 90: 100%|████████████| 19/19 [00:00<00:00, 140.64it/s, loss=0.000967]
# Epoch time: 2.42 s
# Total time elapsed: 248.35 s
# ---------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 91: 100%|██████████████████| 75/75 [00:02<00:00, 32.72it/s, loss=0.000348]
# Validation 91: 100%|██████████████| 19/19 [00:00<00:00, 133.01it/s, loss=0.0008]
# Epoch time: 2.44 s
# Total time elapsed: 250.84 s
# ---------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 92: 100%|██████████████████| 75/75 [00:02<00:00, 32.99it/s, loss=0.000347]
# Validation 92: 100%|████████████| 19/19 [00:00<00:00, 138.71it/s, loss=0.000684]
# Epoch time: 2.42 s
# Total time elapsed: 253.31 s
# ---------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 93: 100%|██████████████████| 75/75 [00:02<00:00, 32.84it/s, loss=0.000316]
# Validation 93: 100%|████████████| 19/19 [00:00<00:00, 141.67it/s, loss=0.000998]
# Epoch time: 2.42 s
# Total time elapsed: 255.78 s
# ---------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 94: 100%|██████████████████| 75/75 [00:02<00:00, 32.82it/s, loss=0.000339]
# Validation 94: 100%|█████████████| 19/19 [00:00<00:00, 141.22it/s, loss=0.00108]
# Epoch time: 2.43 s
# Total time elapsed: 258.25 s
# ---------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 95: 100%|██████████████████| 75/75 [00:02<00:00, 32.71it/s, loss=0.000376]
# Validation 95: 100%|████████████| 19/19 [00:00<00:00, 147.72it/s, loss=0.000632]
# Epoch time: 2.43 s
# Total time elapsed: 260.73 s
# ---------------------------------------
# EarlyStopping counter: 9 out of 20
# Epoch 96: 100%|██████████████████| 75/75 [00:02<00:00, 33.01it/s, loss=0.000331]
# Validation 96: 100%|█████████████| 19/19 [00:00<00:00, 137.28it/s, loss=0.00082]
# Epoch time: 2.42 s
# Total time elapsed: 263.20 s
# ---------------------------------------
# EarlyStopping counter: 10 out of 20
# Epoch 97: 100%|██████████████████| 75/75 [00:02<00:00, 32.85it/s, loss=0.000367]
# Validation 97: 100%|████████████| 19/19 [00:00<00:00, 142.89it/s, loss=0.000717]
# Epoch time: 2.42 s
# Total time elapsed: 265.67 s
# ---------------------------------------
# EarlyStopping counter: 11 out of 20
# Epoch 98: 100%|███████████████████| 75/75 [00:02<00:00, 32.87it/s, loss=0.00033]
# Validation 98: 100%|█████████████| 19/19 [00:00<00:00, 139.05it/s, loss=0.00086]
# Epoch time: 2.42 s
# Total time elapsed: 268.14 s
# ---------------------------------------
# EarlyStopping counter: 12 out of 20
# Epoch 99: 100%|██████████████████| 75/75 [00:02<00:00, 32.87it/s, loss=0.000325]
# Validation 99: 100%|████████████| 19/19 [00:00<00:00, 145.69it/s, loss=0.000874]
# Epoch time: 2.42 s
# Total time elapsed: 270.61 s
# ---------------------------------------
# EarlyStopping counter: 13 out of 20
# Epoch 100: 100%|█████████████████| 75/75 [00:02<00:00, 32.42it/s, loss=0.000301]
# Validation 100: 100%|███████████| 19/19 [00:00<00:00, 125.70it/s, loss=0.000723]
# Epoch time: 2.47 s
# Total time elapsed: 273.15 s
# ---------------------------------------
# EarlyStopping counter: 14 out of 20
# Epoch 101: 100%|█████████████████| 75/75 [00:02<00:00, 32.67it/s, loss=0.000342]
# Validation 101: 100%|███████████| 19/19 [00:00<00:00, 118.18it/s, loss=0.000673]
# Epoch time: 2.46 s
# Total time elapsed: 275.68 s
# ---------------------------------------
# EarlyStopping counter: 15 out of 20
# Epoch 102: 100%|█████████████████| 75/75 [00:02<00:00, 32.13it/s, loss=0.000311]
# Validation 102: 100%|███████████| 19/19 [00:00<00:00, 139.27it/s, loss=0.000919]
# Epoch time: 2.48 s
# Total time elapsed: 278.20 s
# ---------------------------------------
# EarlyStopping counter: 16 out of 20
# Epoch 103: 100%|█████████████████| 75/75 [00:02<00:00, 29.34it/s, loss=0.000318]
# Validation 103: 100%|███████████| 19/19 [00:00<00:00, 114.63it/s, loss=0.000785]
# Epoch time: 2.73 s
# Total time elapsed: 280.98 s
# ---------------------------------------
# Validation loss decreased (0.000754 --> 0.000747).  Saving model ...
# Epoch 104: 100%|█████████████████| 75/75 [00:02<00:00, 32.57it/s, loss=0.000332]
# Validation 104: 100%|███████████| 19/19 [00:00<00:00, 140.83it/s, loss=0.000696]
# Epoch time: 2.45 s
# Total time elapsed: 283.56 s
# ---------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 105: 100%|█████████████████| 75/75 [00:02<00:00, 32.80it/s, loss=0.000345]
# Validation 105: 100%|███████████| 19/19 [00:00<00:00, 137.38it/s, loss=0.000903]
# Epoch time: 2.43 s
# Total time elapsed: 286.04 s
# ---------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 106: 100%|█████████████████| 75/75 [00:02<00:00, 32.52it/s, loss=0.000304]
# Validation 106: 100%|███████████| 19/19 [00:00<00:00, 114.81it/s, loss=0.000563]
# Epoch time: 2.48 s
# Total time elapsed: 288.58 s
# ---------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 107: 100%|█████████████████| 75/75 [00:02<00:00, 32.82it/s, loss=0.000301]
# Validation 107: 100%|███████████| 19/19 [00:00<00:00, 136.80it/s, loss=0.000899]
# Epoch time: 2.43 s
# Total time elapsed: 291.05 s
# ---------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 108: 100%|█████████████████| 75/75 [00:02<00:00, 32.56it/s, loss=0.000374]
# Validation 108: 100%|███████████| 19/19 [00:00<00:00, 136.70it/s, loss=0.000751]
# Epoch time: 2.45 s
# Total time elapsed: 293.55 s
# ---------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 109: 100%|█████████████████| 75/75 [00:02<00:00, 32.88it/s, loss=0.000313]
# Validation 109: 100%|████████████| 19/19 [00:00<00:00, 140.02it/s, loss=0.00064]
# Epoch time: 2.42 s
# Total time elapsed: 296.03 s
# ---------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 110: 100%|█████████████████| 75/75 [00:02<00:00, 33.10it/s, loss=0.000305]
# Validation 110: 100%|███████████| 19/19 [00:00<00:00, 144.46it/s, loss=0.000662]
# Epoch time: 2.40 s
# Total time elapsed: 298.48 s
# ---------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 111: 100%|█████████████████| 75/75 [00:02<00:00, 32.60it/s, loss=0.000296]
# Validation 111: 100%|███████████| 19/19 [00:00<00:00, 137.59it/s, loss=0.000764]
# Epoch time: 2.45 s
# Total time elapsed: 300.97 s
# ---------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 112: 100%|█████████████████| 75/75 [00:02<00:00, 32.69it/s, loss=0.000314]
# Validation 112: 100%|████████████| 19/19 [00:00<00:00, 141.28it/s, loss=0.00084]
# Epoch time: 2.44 s
# Total time elapsed: 303.46 s
# ---------------------------------------
# EarlyStopping counter: 9 out of 20
# Epoch 113: 100%|█████████████████| 75/75 [00:02<00:00, 32.92it/s, loss=0.000288]
# Validation 113: 100%|████████████| 19/19 [00:00<00:00, 138.01it/s, loss=0.00062]
# Epoch time: 2.42 s
# Total time elapsed: 305.93 s
# ---------------------------------------
# EarlyStopping counter: 10 out of 20
# Epoch 114: 100%|█████████████████| 75/75 [00:02<00:00, 32.65it/s, loss=0.000261]
# Validation 114: 100%|████████████| 19/19 [00:00<00:00, 132.40it/s, loss=0.00092]
# Epoch time: 2.45 s
# Total time elapsed: 308.42 s
# ---------------------------------------
# EarlyStopping counter: 11 out of 20
# Epoch 115: 100%|█████████████████| 75/75 [00:02<00:00, 32.63it/s, loss=0.000319]
# Validation 115: 100%|███████████| 19/19 [00:00<00:00, 146.31it/s, loss=0.000844]
# Epoch time: 2.44 s
# Total time elapsed: 310.91 s
# ---------------------------------------
# EarlyStopping counter: 12 out of 20
# Epoch 116: 100%|█████████████████| 75/75 [00:02<00:00, 33.01it/s, loss=0.000304]
# Validation 116: 100%|███████████| 19/19 [00:00<00:00, 137.57it/s, loss=0.000598]
# Epoch time: 2.42 s
# Total time elapsed: 313.37 s
# ---------------------------------------
# EarlyStopping counter: 13 out of 20
# Epoch 117: 100%|█████████████████| 75/75 [00:02<00:00, 32.68it/s, loss=0.000311]
# Validation 117: 100%|████████████| 19/19 [00:00<00:00, 136.39it/s, loss=0.00093]
# Epoch time: 2.44 s
# Total time elapsed: 315.86 s
# ---------------------------------------
# EarlyStopping counter: 14 out of 20
# Epoch 118: 100%|██████████████████| 75/75 [00:02<00:00, 32.30it/s, loss=0.00029]
# Validation 118: 100%|███████████| 19/19 [00:00<00:00, 145.75it/s, loss=0.000594]
# Epoch time: 2.46 s
# Total time elapsed: 318.37 s
# ---------------------------------------
# EarlyStopping counter: 15 out of 20
# Epoch 119: 100%|█████████████████| 75/75 [00:02<00:00, 32.80it/s, loss=0.000301]
# Validation 119: 100%|████████████| 19/19 [00:00<00:00, 142.74it/s, loss=0.00104]
# Epoch time: 2.43 s
# Total time elapsed: 320.85 s
# ---------------------------------------
# EarlyStopping counter: 16 out of 20
# Epoch 120: 100%|█████████████████| 75/75 [00:02<00:00, 33.03it/s, loss=0.000299]
# Validation 120: 100%|███████████| 19/19 [00:00<00:00, 137.68it/s, loss=0.000795]
# Epoch time: 2.42 s
# Total time elapsed: 323.31 s
# ---------------------------------------
# EarlyStopping counter: 17 out of 20
# Epoch 121: 100%|██████████████████| 75/75 [00:02<00:00, 32.45it/s, loss=0.00034]
# Validation 121: 100%|████████████| 19/19 [00:00<00:00, 137.90it/s, loss=0.00101]
# Epoch time: 2.46 s
# Total time elapsed: 325.82 s
# ---------------------------------------
# EarlyStopping counter: 18 out of 20
# Epoch 122: 100%|█████████████████| 75/75 [00:02<00:00, 32.77it/s, loss=0.000292]
# Validation 122: 100%|███████████| 19/19 [00:00<00:00, 140.31it/s, loss=0.000963]
# Epoch time: 2.43 s
# Total time elapsed: 328.30 s
# ---------------------------------------
# EarlyStopping counter: 19 out of 20
# Epoch 123: 100%|█████████████████| 75/75 [00:02<00:00, 32.57it/s, loss=0.000324]
# Validation 123: 100%|███████████| 19/19 [00:00<00:00, 138.74it/s, loss=0.000827]
# Epoch time: 2.45 s
# Total time elapsed: 330.80 s
# ---------------------------------------
# EarlyStopping counter: 20 out of 20
# Early stopping

# %% [markdown]
# ### Plot results

# %%
# Acquisition information

x0 = 0.14 # Near offset
dx = 0.09 # Offset increment
dt = 0.008 # Time step

# %%
model.eval()

idx = torch.randint(len(test_data), (4,))
print(idx)

inputs_embeds = test_data.encodings['inputs_embeds'][idx]
labels = test_data.encodings['labels'][idx]
with torch.no_grad():
    sample_output = model(inputs_embeds=inputs_embeds.to(device).float())

for X, y, z in zip(inputs_embeds.cpu(), sample_output.logits.cpu(), labels.cpu()):
    f, ax = plt.subplots(2, 3, figsize=(10, 8), sharey=True, sharex=False)
    f.tight_layout()
    ax[0, 0].imshow(1 * (X - X.mean()).detach().swapaxes(0, 1) * 1, aspect=1.1, vmin=-1, vmax=1, cmap='seismic', 
                   extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[0, 0].set_title("Input", fontsize=14)
    ax[0, 0].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[0, 0].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[0, 0].set_yticks(np.arange(0, 2.5, 0.5))
    ax[0, 0].yaxis.set_minor_locator(AutoMinorLocator(2))
    ax[0, 0].set_ylabel("t (s)")
    ax[0, 1].imshow(1 * (y - y.mean()).detach().swapaxes(0, 1) * 1, aspect=1.1, vmin=-1, vmax=1, cmap='seismic',
                   extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[0, 1].set_title("Denoised", fontsize=14)
    ax[0, 1].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[0, 1].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[0, 1].set_yticks(np.arange(0, 2.5, 0.5))
    diff3 = 1 * (X - y)
    ax[0, 2].imshow((diff3 - diff3.mean()).detach().swapaxes(0, 1), aspect=1.1, vmin=-1, vmax=1, cmap='seismic',
                   extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[0, 2].set_title("(Input - Denoised)", fontsize=14)
    ax[0, 2].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[0, 2].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[0, 2].set_yticks(np.arange(0, 2.5, 0.5))
    diff1 = z
    ax[1, 0].imshow(1 * (diff1 - diff1.mean()).detach().swapaxes(0, 1) * 1, aspect=1.1, vmin=-1, vmax=1, cmap='seismic',
                   extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[1, 0].set_title("Label", fontsize=14)
    ax[1, 0].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[1, 0].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[1, 0].set_yticks(np.arange(0, 2.5, 0.5))
    ax[1, 0].yaxis.set_minor_locator(AutoMinorLocator(2))
    ax[1, 0].set_xlabel("Offset (km)")
    ax[1, 0].set_ylabel("t (s)")
    diff2 = 1 * (z - y)
    im4 = ax[1, 1].imshow((diff2 - diff2.mean()).detach().swapaxes(0, 1), aspect=1.1, vmin=-1, vmax=1, cmap='seismic',
                         extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[1, 1].set_title("(Label - Denoised)", fontsize=14)
    ax[1, 1].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[1, 1].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[1, 1].set_yticks(np.arange(0, 2.5, 0.5))
    ax[1, 1].set_xlabel("Offset (km)")
    diff4 = 1 * (X - z)
    ax[1, 2].imshow((diff4 - diff4.mean()).detach().swapaxes(0, 1), aspect=1.1, vmin=-1, vmax=1, cmap='seismic',
                   extent=[x0, x0 + 20 * dx, 271 * dt, 0])
    ax[1, 2].set_title("(Input - Label)", fontsize=14)
    ax[1, 2].set_xticks([x0, 0.5, 1, 1.5, 1.9])
    ax[1, 2].set_xticklabels([".14", "0.5", "1.0", "1.5", "1.9"])
    ax[1, 2].set_yticks(np.arange(0, 2.5, 0.5))
    ax[1, 2].set_xlabel("Offset (km)")
    
    plt.ylim(2.01, 0)
    
    cbar_ax = f.add_axes([1, 0.15, 0.0175, 0.7])
    cbar = f.colorbar(im4, cax=cbar_ax)
    cbar.set_ticks(np.arange(-1, 1.25, .25))
    cbar.set_ticklabels([-1, "", "", "", "", "", "", "", 1])
# Out:
# tensor([ 56,  14, 224, 188])

# %% [markdown]
# ## Finalize

# %%
# Save everything
print("Saving to", config.parent_dir)
if os.path.exists(os.path.join(config.parent_dir, 'model.pt')):
    if input("Path exists. Overwrite? (y/n)") == 'y':
        torch.save(model, os.path.join(config.parent_dir, 'model.pt'))
        avg_train_loss_arr = np.array(avg_train_loss)
        avg_valid_loss_arr = np.array(avg_valid_loss)
        np.save(os.path.join(config.parent_dir, 'train_loss.npy'), avg_train_loss_arr)
        np.save(os.path.join(config.parent_dir, 'valid_loss.npy'), avg_valid_loss_arr)
        torch.save(config, os.path.join(config.parent_dir, 'config.pt'))
        print("Saved successfully to", config.parent_dir)
    else:
        print("Saving failed.")
else:
    torch.save(model, os.path.join(config.parent_dir, 'model.pt'))
    avg_train_loss_arr = np.array(avg_train_loss)
    avg_valid_loss_arr = np.array(avg_valid_loss)
    np.save(os.path.join(config.parent_dir, 'train_loss.npy'), avg_train_loss_arr)
    np.save(os.path.join(config.parent_dir, 'valid_loss.npy'), avg_valid_loss_arr)
    torch.save(config, os.path.join(config.parent_dir, 'config.pt'))
    print("Saved successfully to", config.parent_dir)
# Out:
# Saving to ./results/finetune/denoising/
# Path exists. Overwrite? (y/n)n
# Saving failed.
